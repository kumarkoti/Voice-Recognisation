# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv('/content/drive/MyDrive/content/voice.csv')
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
data.corr()
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# sd       -0.739039  1.000000 -0.562603 -0.846931 -0.161076  0.874660
# median    0.925445 -0.562603  1.000000  0.774922  0.731849 -0.477352
# Q25       0.911416 -0.846931  0.774922  1.000000  0.477140 -0.874189
# Q75       0.740997 -0.161076  0.731849  0.477140  1.000000  0.009636
# IQR      -0.627605  0.874660 -0.477352 -0.874189  0.009636  1.000000
# skew     -0.322327  0.314597 -0.257407 -0.319475 -0.206339  0.249497
# kurt     -0.316036  0.346241 -0.243382 -0.350182 -0.148881  0.316185
# sp.ent   -0.601203  0.716620 -0.502005 -0.648126 -0.174905  0.640813
# sfm      -0.784332  0.838086 -0.661690 -0.766875 -0.378198  0.663601
# mode      0.687715 -0.529150  0.677433  0.591277  0.486857 -0.403764
# centroid  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# meanfun   0.460844 -0.466281  0.414909  0.545035  0.155091 -0.534462
# ...

# %%
print("Total numbers of labels in the dataste : {}".format(data.shape[0]))
print("Count of male category: {}".format(data[data.label == 'male'].shape[0]))
print("Count of female category: {}".format(data[data.label == 'female'].shape[0]))
# Out:
# Total numbers of labels in the dataste : 3168
# Count of male category: 1584
# Count of female category: 1584

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(data.iloc[ : , : -1].values, data.iloc[ : ,  -1].values, test_size=0.2)

# %%
X_train
# Out:
# array([[0.19016589, 0.03189056, 0.19446355, ..., 6.359375  , 6.2578125 ,
#         0.13058677],
#        [0.19007164, 0.06071474, 0.20991696, ..., 5.5078125 , 5.3203125 ,
#         0.12595114],
#        [0.21338988, 0.03687732, 0.21608018, ..., 8.8828125 , 8.859375  ,
#         0.10351596],
#        ...,
#        [0.189245  , 0.0601139 , 0.17760243, ..., 5.109375  , 5.0859375 ,
#         0.10868832],
#        [0.19101377, 0.06432303, 0.21554832, ..., 4.9453125 , 4.921875  ,
#         0.14372294],
#        [0.19772284, 0.04348425, 0.19699192, ..., 7.        , 6.8515625 ,
#         0.25863572]])

# %%
from sklearn.svm import SVC
classifier1 = SVC(kernel = 'rbf')
classifier1.fit(X_train, y_train)
print('Support Vector Machine:')

print('Accuracy of SVM: {:.2f}'.format(classifier1.score(X_test,y_test)))
# Out:
# Support Vector Machine:
# Accuracy of SVM: 0.69

# %% [markdown]
# # Machine Learning Models

# %% [markdown]
# ## Using Logistic regression

# %%
# importing logistic regression from scikit learn
from sklearn.linear_model import LogisticRegression

# %%
# logistic regression model
log_model = LogisticRegression()

# %%
# fitting the model
log_model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
# prediction on test data
y_predictions = log_model.predict(X_test)

# %% [markdown]
# ### Metrics

# %%
# importing metrics for evaulation of model
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

# %%
# classification report of the model
print(classification_report(y_test,y_predictions))
# Out:
#               precision    recall  f1-score   support
#
#       female       0.95      0.84      0.89       328
#         male       0.84      0.95      0.89       306
#
#     accuracy                           0.89       634
#    macro avg       0.90      0.89      0.89       634
# weighted avg       0.90      0.89      0.89       634

# %%
# confusion matrix
print("Confusion matrix : \n", confusion_matrix(y_test,y_predictions))
# Out:
# Confusion matrix :
#  [[274  54]
#  [ 15 291]]

# %%
# f1_score
from sklearn.metrics import f1_score
# f1 score metrics
f1_score_value = f1_score(y_test,y_predictions,average='weighted')
print("F1 score : ", f1_score_value)
# Out:
# F1 score :  0.8909875507073485

# %% [markdown]
# ## Using Random Forest

# %%
# importing random forest
from sklearn.ensemble import RandomForestClassifier

# %%
# random forest classifier
randomForestModel = RandomForestClassifier()

# %%
# fitting the data into the model
randomForestModel.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
# predicting the data
predictions = randomForestModel.predict(X_test)

# %% [markdown]
# ### Metrics

# %%
# classification report of the model
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#       female       0.99      0.98      0.98       328
#         male       0.98      0.99      0.98       306
#
#     accuracy                           0.98       634
#    macro avg       0.98      0.98      0.98       634
# weighted avg       0.98      0.98      0.98       634

# %%
print("Confusion matrix : \n",confusion_matrix(y_test,predictions))
# Out:
# Confusion matrix :
#  [[322   6]
#  [  4 302]]

# %%
# f1 score metrics of model
f1_score_value = f1_score(y_test,predictions,average='weighted')
print("F1 score : ", f1_score_value)
# Out:
# F1 score :  0.9842287005127341

# %% [markdown]
# ## Using Decision Tree

# %%
# importing DecisionTreeClassifier from scikit learn
from sklearn.tree import DecisionTreeClassifier

# %%
# Decision Tree Model
decision_tree_model = DecisionTreeClassifier() 
decision_tree_model.fit(X_train,y_train)

# predicting the test data
y_pred = decision_tree_model.predict(X_test)

# %%
# fitting the data into the model
decision_tree_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = decision_tree_model.predict(X_test)

# %% [markdown]
# ### Metrics

# %%
print("Confusion matrix : \n",confusion_matrix(y_test,predictions))
# Out:
# Confusion matrix :
#  [[310  18]
#  [  8 298]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#       female       0.97      0.95      0.96       328
#         male       0.94      0.97      0.96       306
#
#     accuracy                           0.96       634
#    macro avg       0.96      0.96      0.96       634
# weighted avg       0.96      0.96      0.96       634

# %%
# f1 score metrics
f1_score_value = f1_score(y_test,predictions,average='weighted')
print("F1 score : ", f1_score_value)
# Out:
# F1 score :  0.9590027836361847

# %% [markdown]
# ## Using K Nearest neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# K nearest neighbour model
knn_model = KNeighborsClassifier(n_neighbors=2)

# fitting the traning data
knn_model.fit(X_train,y_train)

# predicting the test data
y_pred = knn_model.predict(X_test)

# %%
# accuracy score
accuracy_score_value = accuracy_score(y_test,y_pred)
print("Accuracy Score : ", accuracy_score_value)
# Out:
# Accuracy Score :  0.6892744479495269

# %% [markdown]
# ### Metrics

# %%
# metrics of the model
print("Confusion matrix : \n",confusion_matrix(y_test,y_pred))
# Out:
# Confusion matrix :
#  [[268  60]
#  [137 169]]

# %%
# classification report of model
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       female       0.66      0.82      0.73       328
#         male       0.74      0.55      0.63       306
#
#     accuracy                           0.69       634
#    macro avg       0.70      0.68      0.68       634
# weighted avg       0.70      0.69      0.68       634

# %%
# f1 score metrics of model
f1_score_value = f1_score(y_test,y_pred,average='weighted')
print("F1 score : ", f1_score_value)
# Out:
# F1 score :  0.6832343340066198

# %% [markdown]
# ## Using ANN Model

# %%
from sklearn import preprocessing

# label encoding
le = preprocessing.LabelEncoder()

y_train_le = le.fit_transform(y_train)
y_test_le = le.fit_transform(y_test)

# %%
# Importing required layers
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv1D, MaxPooling1D

# %%
ann_classifier = Sequential()
# first hidden layer and input layer
ann_classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 20))

# second hidden layer
ann_classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# output layer
ann_classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# compiling the optimizer and loss function according to the data
ann_classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the ANN
ann_classifier.fit(X_train, y_train_le, batch_size = 10, epochs = 200,verbose = 0)

# %% [markdown]
# ### Metrics

# %%
score, acc = ann_classifier.evaluate(X_train, y_train_le,
                            batch_size=10)
print('Train score:', score)
print('Train accuracy:', acc)


# predicting the test results
y_pred = ann_classifier.predict(X_test)
y_pred = (y_pred > 0.5)


score, acc = ann_classifier.evaluate(X_test, y_test_le,
                            batch_size=10)
print('Test score:', score)
print('Test accuracy:', acc)

# confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test_le, y_pred)
print(cm)
# Out:
# 254/254 [==============================] - 1s 4ms/step - loss: 0.0893 - accuracy: 0.9676
# Train score: 0.0892816036939621
# Train accuracy: 0.9676401019096375
# 64/64 [==============================] - 0s 3ms/step - loss: 0.1221 - accuracy: 0.9527
# Test score: 0.12208440154790878
# Test accuracy: 0.9526813626289368
# [[305  23]
#  [  7 299]]

# %%
# f1_score
from sklearn.metrics import f1_score
# f1 score metrics
f1_score_value = f1_score(y_test_le,y_pred,average='weighted')
print("F1 score : ", f1_score_value)
# Out:
# F1 score :  0.9526926902288575

# %% [markdown]
# ## Summary of models

# %%
# details of the metrics

Models = ["Logistic Regression", "Random Forest", "Decision Tree","K Nearest Neighbour","ANN Model"]


models_accuracy = [89, 98, 98,68,95.2]
models_f1_score = [89, 98, 95,68,95.2]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 9))

#Bar plot of Accuracy Score of the models
plt.bar(Models, models_accuracy, color = "red")
plt.xlabel("Models") 
plt.ylabel("Accuracy score") 
plt.title("Accuracy graph") 
plt.show()


plt.figure(figsize=(12, 9))

# Bar plot of F1 score of models 
plt.bar(Models, models_f1_score, color = "green")
plt.xlabel("Models") 
plt.ylabel("F1 score") 
plt.title("F1 score graph ") 
plt.show()
